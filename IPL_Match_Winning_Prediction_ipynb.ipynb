# %%
import numpy as np # linear algebra
import pandas as pd

# %%
delivery=pd.read_csv('deliveries.csv')

# %%
matches=pd.read_csv('matches.csv')

# %%
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
matches.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
delivery.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
matches.duplicated().sum()
# Out:
# np.int64(0)

# %%
delivery.duplicated().sum()
# Out:
# np.int64(23)

# %%
delivery [delivery.duplicated()]
# Out:
#         match_id  inning                 batting_team  \
# 52178        221       1               Mumbai Indians
# 162805      7946       1             Rajasthan Royals
# 162806      7946       1             Rajasthan Royals
# 162870      7946       1             Rajasthan Royals
# 162964      7946       2  Royal Challengers Bangalore
# 166610     11144       2          Sunrisers Hyderabad
# 167990     11150       1  Royal Challengers Bangalore
# 168080     11150       2             Rajasthan Royals
# 169404     11311       1  Royal Challengers Bangalore
# 170110     11314       1        Kolkata Knight Riders
# 170111     11314       1        Kolkata Knight Riders
# 170117     11314       1        Kolkata Knight Riders
# 170119     11314       1        Kolkata Knight Riders
# 170120     11314       1        Kolkata Knight Riders
# 171685     11320       2          Chennai Super Kings
# 172216     11322       2               Mumbai Indians
# ...

# %%
delivery.shape
# Out:
# (179078, 21)

# %%
matches.shape
# Out:
# (756, 18)

# %% [markdown]
# **Filtering Data**

# %%
df=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
#Changing total runs to target column so adding +1 in each total_runs value

df['total_runs']=df['total_runs'] + 1

# %%
df=df[df['inning']==1]

# %%
df.rename({'total_runs':'target'},axis=1,inplace=True)

# %%
df.drop('inning',axis=1,inplace=True)

# %%
matches
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
df.rename(columns={'match_id':'id'},inplace=True)

# %%
merged_matches=matches.merge(df,on='id')

# %%
merged_matches
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
merged_matches=merged_matches[merged_matches['result']=='normal']

# %%
merged_matches=merged_matches[merged_matches['dl_applied']==0]

# %%
mm=merged_matches

# %%
mm.rename(columns={'id':'match_id'},inplace=True)

# %%
mm['team1']=mm['team1'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
mm['team2']=mm['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
mm['team1']=mm['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad ')

# %%
mm['team2']=mm['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad ')

# %%
mm['team1']=mm['team1'].str.strip()

# %%
mm['team2']=mm['team2'].str.strip()

# %%
mm['team1'].value_counts()
# Out:
# team1
# Sunrisers Hyderabad            102
# Mumbai Indians                 100
# Kings XI Punjab                 88
# Chennai Super Kings             86
# Royal Challengers Bangalore     81
# Kolkata Knight Riders           79
# Delhi Capitals                  71
# Rajasthan Royals                63
# Pune Warriors                   20
# Gujarat Lions                   13
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          6
# Name: count, dtype: int64

# %%
teams_to_remove = ['Rising Pune Supergiants','Rising Pune Supergiant','Kochi Tuskers Kerala','Pune Warriors','Gujarat Lions']

# Remove rows where 'team2' is in the list
mm = mm[~mm['team2'].isin(teams_to_remove)]

# %%
teams_to_remove = ['Rising Pune Supergiants','Rising Pune Supergiant','Kochi Tuskers Kerala','Pune Warriors','Gujarat Lions']

# Remove rows where 'team1' is in the list
mm = mm[~mm['team1'].isin(teams_to_remove)]

# %%
mm['team1'].value_counts()
# Out:
# team1
# Sunrisers Hyderabad            94
# Mumbai Indians                 91
# Chennai Super Kings            81
# Kings XI Punjab                80
# Kolkata Knight Riders          72
# Royal Challengers Bangalore    72
# Delhi Capitals                 65
# Rajasthan Royals               60
# Name: count, dtype: int64

# %%
mm=mm[['match_id','city','winner','target']]

# %%
delivery=delivery.merge(mm,on='match_id')

# %%
#assigning small variable name for comfort
dl=delivery

# %%
dl=dl[dl['inning']==2]

# %%
dl['current_score']=dl.groupby('match_id')['total_runs'].cumsum()
# Out:
# /tmp/ipython-input-41-2029277757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dl['current_score']=dl.groupby('match_id')['total_runs'].cumsum()

# %%
dl['runs_left']=dl['target']-dl['current_score']
# Out:
# /tmp/ipython-input-42-1616000384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dl['runs_left']=dl['target']-dl['current_score']

# %%
dl=dl[dl['runs_left']>-6]

# %%
dl['balls_left']=126 - (dl['over']*6 + dl['ball'])

# %%
dl
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 125            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 126            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 127            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 128            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 129            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# ...          ...     ...                          ...                  ...
# 147193     11415       2          Chennai Super Kings       Mumbai Indians
# 147194     11415       2          Chennai Super Kings       Mumbai Indians
# 147195     11415       2          Chennai Super Kings       Mumbai Indians
# 147196     11415       2          Chennai Super Kings       Mumbai Indians
# 147197     11415       2          Chennai Super Kings       Mumbai Indians
#
# ...

# %%
dl['rrr']=dl['runs_left']/(dl['balls_left']/6)

# %%
dl['crr']=dl['current_score']/((120-dl['balls_left'])/6)

# %%
dl['result']='0'

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
dl['result']=dl.apply(result,axis=1)

# %%
dl['player_dismissed']=dl['player_dismissed'].fillna('0')

# %%
dl['player_dismissed']=dl['player_dismissed'].apply(lambda x: x if x=='0' else 1)

# %%
dl['player_dismissed']=dl['player_dismissed'].astype('int')

# %%
wickets=dl.groupby('match_id')['player_dismissed'].cumsum()

# %%
dl['wickets_left']=10-wickets

# %%
pro=dl[['batting_team','bowling_team','city','target','current_score','runs_left','balls_left','wickets_left','rrr','crr','result']]

# %%
pro.dropna(inplace=True)
# Out:
# /tmp/ipython-input-57-2577406078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pro.dropna(inplace=True)

# %%
pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70526 entries, 125 to 147197
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batting_team   70526 non-null  object
#  1   bowling_team   70526 non-null  object
#  2   city           70526 non-null  object
#  3   target         70526 non-null  int64
#  4   current_score  70526 non-null  int64
#  5   runs_left      70526 non-null  int64
#  6   balls_left     70526 non-null  int64
#  7   wickets_left   70526 non-null  int64
#  8   rrr            70526 non-null  float64
#  9   crr            70526 non-null  float64
#  10  result         70526 non-null  int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 6.5+ MB

# %%
pro.describe()
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#              target  current_score     runs_left    balls_left  wickets_left  \
# count  70526.000000   70526.000000  70526.000000  70526.000000  70526.000000
# mean     166.888013      73.342994     93.545019     62.719494      7.537617
# std       29.330790      46.870683     50.024865     33.359689      2.141998
# min       68.000000       0.000000     -5.000000     -2.000000      0.000000
# 25%      148.000000      34.000000     54.000000     35.000000      6.000000
# 50%      166.000000      70.000000     93.000000     63.000000      8.000000
# 75%      186.000000     109.000000    131.000000     92.000000      9.000000
# max      251.000000     223.000000    250.000000    119.000000     10.000000
#
#                 rrr           crr        result
# ...

# %%
pro=pro[pro['balls_left']!=0]

# %%
pro=pro.sample(pro.shape[0])

# %%
pro
# Out:
#                        batting_team                 bowling_team       city  \
# 7177    Royal Challengers Bangalore        Kolkata Knight Riders  Bangalore
# 109472               Mumbai Indians  Royal Challengers Bangalore     Mumbai
# 48660                Mumbai Indians  Royal Challengers Bangalore  Bangalore
# 98574               Kings XI Punjab        Kolkata Knight Riders    Kolkata
# 78403              Rajasthan Royals  Royal Challengers Bangalore     Jaipur
# ...                             ...                          ...        ...
# 51327               Kings XI Punjab             Delhi Daredevils      Delhi
# 91686   Royal Challengers Bangalore               Mumbai Indians     Mumbai
# 42208              Delhi Daredevils        Kolkata Knight Riders    Kolkata
# 82461              Rajasthan Royals          Chennai Super Kings     Jaipur
# 60772              Delhi Daredevils              Deccan Chargers      Delhi
#
# ...

# %% [markdown]
# TRAINING THE DATA

# %%
from sklearn.model_selection import train_test_split

# %%
x=pro.drop('result',axis=1)
y=pro['result']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,shuffle=False,test_size=.25)

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ct = ColumnTransformer(
    transformers=[
        ('ttf1', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
    ],
    remainder='passthrough'
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline([
    ('step1',ct),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
#Checking the data before fitting the pipeline
xtrain.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# target           0
# current_score    0
# runs_left        0
# balls_left       0
# wickets_left     0
# rrr              0
# crr              0
# dtype: int64

# %%
xtest.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# target           0
# current_score    0
# runs_left        0
# balls_left       0
# wickets_left     0
# rrr              0
# crr              0
# dtype: int64

# %%
pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ttf1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
prediction=pipe.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(ytest,prediction)

# %%
print('Accuracy of our model is:',accuracy)
# Out:
# Accuracy of our model is: 0.8022872098315885

# %%
pipe.predict_proba(xtest)[10]
# Out:
# array([0.95, 0.05])

# %% [markdown]
# **Random Forest Algorithm**

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
pipe=Pipeline([
    ('step1',ct),
    ('step2',rf)
])

# %%
pipe.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ttf1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
prediction2=pipe.predict(xtest)

# %%
accuracy2=accuracy_score(ytest,prediction2)

# %%
print('The accuracy of Random forest is:',accuracy2)
# Out:
# The accuracy of Random forest is: 0.9982931269913519
